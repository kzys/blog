# %% [markdown]
# # Blogging with Jupyter
#
# date: 2019-12-25T08:09:32-08:00
#
# <!--eofm-->

# %% [markdown]
# I've added [nb2hugo](https://github.com/vlunot/nb2hugo) on this blog. This article is directly converted from a Juputer notebook.

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 3*np.pi, 500)
plt.plot(x, np.sin(x**2))
