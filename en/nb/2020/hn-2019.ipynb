# %% [markdown]
# # Hacker News in 2019
# date: 2020-01-01T07:12:54-08:00
# <!--eofm-->

# %% [markdown]
# This is a re-run of [Looking back 2017, through Hacker News](https://blog.8-p.info/en/2018/01/01/hacker-news-2017/), which was inspired by [Looking back at 9 years of Hacker News](http://debarghyadas.com/writes/looking-back-at-9-years-of-hacker-news/).

# %% [markdown]
# ## Python basics

# %% [markdown]
# Previously I was using `%bq` magic, but it seems deprecated, according to [Migrating from the datalab Python package](https://cloud.google.com/bigquery/docs/datalab-migration).
#
# For the BigQuery client library, I need to [setup authentication by setting GOOGLE_APPLICATION_CREDENTIALS environment variable](https://cloud.google.com/bigquery/docs/reference/libraries#setting_up_authentication). Without that, you would get `Project was not passed and could not be determined from the environment`.

# %%
from google.cloud import bigquery

# %%
# %load_ext google.cloud.bigquery
# Out:
# The google.cloud.bigquery extension is already loaded. To reload it, use:
#   %reload_ext google.cloud.bigquery

# %%
# %%bigquery
# SELECT title, url, score, id, timestamp FROM `bigquery-public-data.hacker_news.full`
# WHERE type = 'story' AND extract(year FROM timestamp) = 2019
# ORDER BY score DESC LIMIT 30
# Out:
#                                                 title  \
# 0                       Switch from Chrome to Firefox
# 1                       I Sell Onions on the Internet
# 2             Announcing unlimited free private repos
# 3           Slack’s new WYSIWYG input box is terrible
# 4   Show HN: A retro video game console I've been ...
# 5                         My Business Card Runs Linux
# 6   Blizzard Suspends Professional Hearthstone Pla...
# 7                                      Raspberry Pi 4
# 8                Twitter to ban political advertising
# 9                            No Thank You, Mr. Pecker
# 10                  Julian Assange arrested in London
# 11                                          Save .org
# 12  Otonomo, with nearly $55M in funding, is cloni...
# 13    Mazda is purging touchscreens from its vehicles
# 14                           A Conspiracy to Kill IE6
# 15  Unveiling the first-ever image of a black hole...
# 16  Reflecting on My Failure to Build a Billion-Do...
# 17                       Ken Thompson's Unix Password
# 18  Google to restrict modern ad blocking Chrome e...
# 19                                    GitHub Sponsors
# 20  Court: Suspicionless Searches of Travelers’ Ph...
# 21  Firefox Send: Free encrypted file transfer ser...
# 22  The boring technology behind a one-person Inte...
# 23  Ask HN: What books changed the way you think a...
# 24                                        Having Kids
# 25                    California bans private prisons
# 26  Vulnerability in the Mac Zoom client allows ma...
# 27                          Google Is Eating Our Mail
# 28                             Joe Armstrong has died
# 29  I tried creating a web browser, and Google blo...
#
#                                                   url  score        id  \
# 0       https://www.mozilla.org/en-US/firefox/switch/   3287  20052623
# 1   https://www.deepsouthventures.com/i-sell-onion...   3015  19728132
# 2   https://blog.github.com/2019-01-07-new-year-ne...   2867  18847043
# 3   https://quuxplusone.github.io/blog/2019/11/20/...   2776  21589647
# 4   https://internalregister.github.io/2019/03/14/...   2690  19393279
# 5   https://www.thirtythreeforty.net/posts/2019/12...   2584  21871026
